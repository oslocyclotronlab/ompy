# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import sys, os
import ompy
import copy
# %autoreload 2
# %matplotlib inline

# %%
# Import raw matrix into instance of om.Matrix() and plot it
fname_raw = "../tests/mock/Dy164_raw.m"
raw = ompy.Matrix(filename=fname_raw)
raw.plot(title="raw")

# %%
# Cut away diagonal
#raw_diagcut = copy.copy(raw)
#raw_diagcut.matrix = om.cut_diagonal(raw.matrix, raw.E0_array, raw.E1_array, E1, E2)
raw.cut_diagonal([0, 800], [7300, 7500])
raw.plot()

# %%
# Import raw matrix into instance of om.Matrix() and plot it
fname_raw = "../tests/mock/Dy164_raw.m"
raw2 = ompy.Matrix(filename=fname_raw)
fig, ax = plt.subplots(ncols=3, figsize=(9, 3))
ax[0].pcolormesh(raw2.E1_array, raw2.E0_array, raw2.matrix, norm=LogNorm())
raw2.cut_diagonal([0, 800], [7300, 7500])
ax[1].pcolormesh(raw2.E1_array, raw2.E0_array, raw2.matrix, norm=LogNorm())
ax[2].pcolormesh(raw2.E1_array, raw2.E0_array, raw2.matrix, norm=LogNorm())
ax[2].set_xlim(0, 8000)
ax[2].set_ylim(0, 8000)
[a.axis('off') for a in ax]
plt.savefig('../resources/demo.png')

# %%
raw2.range_E0 = np.array([1,2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-26803b524c6f> in <module>
# ----> 1 raw2.range_E0 = np.array([1,2])
#
# AttributeError: can't set attribute

# %%
raw2.E0_array[7]
# Out:
# 80.0

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
plt.matshow(ompy.Matrix(filename=fname_raw).matrix, norm=LogNorm())
