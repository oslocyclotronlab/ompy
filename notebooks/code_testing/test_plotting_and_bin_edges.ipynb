# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, "../../")
import ompy

# %load_ext autoreload

# %%
# The MAMA file Si28_raw_matrix_compressed.m has the calibration coefficients  
# Egamma: a0 = 52.5000, a1 = 112.000
# Ex:     a0 = -453.500, a1 = 124.000
# Recall that MAMA uses middle-bin calibration.

# Compare to OMpy to check that we are plotting it right, and not shifting by half a channel or even more:
raw = ompy.read_mama_2D("Si28_raw_matrix_compressed.m")
print(raw.calibration())
print(raw.E1_array.max())
# Out:
# {'a00': -515.5, 'a01': 124.0, 'N0': 125, 'a10': -3.5, 'a11': 112.0, 'N1': 125}
# 13884.5

# %%
raw.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
raw.plot_projection_x([3000, 3500])
# Out:
# <img src="data:image/png;base64,..." width="640">
